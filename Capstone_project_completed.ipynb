# %% [markdown]
# # Data Science Capstone Project - Full Project
#
# ### Introduction

# %% [markdown]
# The goal in this project is to recommend a best place to stay during the holiday in London

# %% [markdown]
# ## Business case

# %% [markdown]
# London is one of the largest cities in Europe - thousands of tourists visit this city every day. The first and obvious step in holiday-planning is - "Where we will stay" ? Then the real problem begins. Hundreds of places to sleep and hundreds of places to visit. Searching through the web might be inefficient as we would need to check tens of pages...
#
# ...and here is where we are coming with help

# %% [markdown]
# ### Problems

# %% [markdown]
# We are here to recommend the best choice of stay in London, but how we are going to do it ?
#
# Couple of questions come into consideration
#
# + How do we find hotels ?
# + How do we grade them ?
# + From where we obtain the data

# %% [markdown]
# ### Resolution

# %% [markdown]
# #### First, lets describe the data source:
#
# All the data comes from Foursquare API - powerful application which contains geospatial data from all over the world. By using it, we will have access to all the hotel data in London as well as nearby venues which will help with recommendation process
#
# #### Second - grading method:
#
# We are going to assume that the best hotel would be the one, which has the highest online rating and has the most venues nearby.
#
# Having those 2 questions answered - we have the fundamentals to resolve that 'hotel issue in London'
#
# The final form of the recommendation will be the list of 5 best hotels using the assumptions above - This will surely help the people coming here :)

# %% [markdown]
# ***

# %% [markdown]
# # Data

# %% [markdown]
# Using GeoPy Python's library we are going to obtain the geographic localization of London. Once its done, utlizing Foursquare API, we are going to get full list of the hotels in the range of 10 km from the central city point. Once done, we will get online ratings for each hotel - this will help us to choose 5 best hotels in London. Once hotels are chosen, we will find nearby venues in the range of 1km from the hotel. The best hotel would be with highest online rating + with highest number of venues in a neighbourhood. All this data will be obtained using Foursquare API
#
# Having in mind that venues might be in range of more than 1 hotel - we will use K-Means method to cluster them

# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 2)

# %% [markdown]
# #### First We are going to import relevant libraries

# %%
import requests
import pandas as pd 
import numpy as np


# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

from pandas.io.json import json_normalize

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed')
print('All Libraries imported.')
# Out:
# Collecting package metadata: done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - anaconda/linux-64::conda-build==3.17.8=py36_0
#   - anaconda/linux-64::grpcio==1.16.1=py36hf8bcb03_1
#   - anaconda/linux-64::keras==2.1.5=py36_0
#   - anaconda/linux-64::libarchive==3.3.3=h5d8350f_5
#   - anaconda/linux-64::python-libarchive-c==2.8=py36_6
#   - anaconda/linux-64::tensorboard==1.8.0=py36hf484d3e_0
#   - anaconda/linux-64::tensorflow==1.8.0=h57681fa_0
#   - anaconda/linux-64::tensorflow-base==1.8.0=py36h5f64886_0
#   - defaults/linux-64::anaconda==5.3.1=py37_0
#   - defaults/linux-64::astropy==3.0.4=py37h14c3975_0
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::bokeh==0.13.0=py37_0
#   - defaults/linux-64::bottleneck==1.2.1=py37h035aef0_1
#   - defaults/linux-64::dask==0.19.1=py37_0
#   - defaults/linux-64::datashape==0.5.4=py37_1
#   - defaults/linux-64::mkl-service==1.1.2=py37h90e4bf4_5
#   - defaults/linux-64::numba==0.39.0=py37h04863e7_0
#   - defaults/linux-64::numexpr==2.6.8=py37hd89afb7_0
#   - defaults/linux-64::odo==0.5.1=py37_0
#   - defaults/linux-64::pytables==3.4.4=py37ha205bf6_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py37_0
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py37_0
#   - defaults/linux-64::pywavelets==1.0.0=py37hdd07704_0
#   - defaults/linux-64::scikit-image==0.14.0=py37hf484d3e_1
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.7.5                |           py36_0         3.0 MB  conda-forge
#     conda-package-handling-1.3.11|           py36_0         257 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     libarchive-3.3.3           |    hb44662c_1005         1.4 MB  conda-forge
#     libiconv-1.15              |    h516909a_1005         2.0 MB  conda-forge
#     libxml2-2.9.9              |       h13577e0_1         1.3 MB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     python-libarchive-c-2.8    |        py36_1004          21 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        10.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   conda-package-han~ conda-forge/linux-64::conda-package-handling-1.3.11-py36_0
#   geographiclib      conda-forge/noarch::geographiclib-1.49-py_0
#   libiconv           conda-forge/linux-64::libiconv-1.15-h516909a_1005
#
# The following packages will be UPDATED:
#
#   conda                       anaconda::conda-4.6.14-py36_0 --> conda-forge::conda-4.7.5-py36_0
#   geopy              conda-forge/linux-64::geopy-1.11.0-py~ --> conda-forge/noarch::geopy-1.20.0-py_0
#   libarchive          anaconda::libarchive-3.3.3-h5d8350f_5 --> conda-forge::libarchive-3.3.3-hb44662c_1005
#   libxml2               pkgs/main::libxml2-2.9.8-h26e45fe_1 --> conda-forge::libxml2-2.9.9-h13577e0_1
#   openssl                                 1.1.1b-h14c3975_1 --> 1.1.1c-h516909a_0
#   python-libarchive~ anaconda::python-libarchive-c-2.8-py3~ --> conda-forge::python-libarchive-c-2.8-py36_1004
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# conda-4.7.5          | 3.0 MB    | ##################################### | 100%
# python-libarchive-c- | 21 KB     | ##################################### | 100%
# libiconv-1.15        | 2.0 MB    | ##################################### | 100%
# libxml2-2.9.9        | 1.3 MB    | ##################################### | 100%
# conda-package-handli | 257 KB    | ##################################### | 100%
# libarchive-3.3.3     | 1.4 MB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# WARNING conda.base.context:use_only_tar_bz2(632): Conda is constrained to only using the old .tar.bz2 file format because you have conda-build installed, and it is <3.18.3.  Update or remove conda-build to get smaller downloads and faster extractions.
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - anaconda/linux-64::grpcio==1.16.1=py36hf8bcb03_1 -> openssl[version='>=1.1.1,<1.1.2.0a0']
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Folium installed
# All Libraries imported.

# %%
CLIENT_ID = 'O3NRWAGDP04G21IH4OIYVB1GFQ1PE3HG1CEVBX5UWSS2CCOV' # your Foursquare ID
CLIENT_SECRET = 'HQFJUH4TZCC5ZZKX3USGUUUWGXDRPFQKAJGPR1GXFSSNNL3A' # your Foursquare Secret
VERSION = '20190713'

# %% [markdown]
# ### Using GeoPy library, we can obtain the geospatial position of London

# %%
address = 'London'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 51.5073219 -0.1276474

# %% [markdown]
# # Given we have position of London, we can find hotels in a range of 10km

# %%
search_query = 'hotels'
radius = 10000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius)
result_hotels = requests.get(url).json()
result_hotels
# Out:
# {'meta': {'code': 200, 'requestId': '5d2bb410bf7dde002c7d2e99'},
#  'response': {'venues': [{'id': '5afb9f1b65211f002c89d942',
#     'name': 'Global Great Hotels - Investments Real Estate',
#     'location': {'address': '133 Cockfosters Rd',
#      'lat': 51.50708638980144,
#      'lng': -0.12790918350219727,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50708638980144,
#        'lng': -0.12790918350219727}],
#      'distance': 31,
#      'postalCode': 'EN4 0AA',
#      'cc': 'GB',
#      'city': 'Hertfordshire',
#      'state': 'Hertfordshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['133 Cockfosters Rd',
#       'Hertfordshire',
#       'EN4 0AA',
#       'United Kingdom']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4bc1e83c2a89ef3b78daf288',
#     'name': 'Millennium & Copthorne Hotels',
#     'location': {'address': 'Stamford Bridge Fulham Road',
#      'crossStreet': 'Fulham Road',
#      'lat': 51.4810573,
#      'lng': -0.189093,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.4810573,
#        'lng': -0.189093}],
#      'distance': 5165,
#      'postalCode': 'SW6 1HS',
#      'cc': 'GB',
#      'city': 'Chelsea',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Stamford Bridge Fulham Road (Fulham Road)',
#       'Chelsea',
#       'Greater London',
#       'SW6 1HS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '50eb1154e4b0541e75c25274',
#     'name': "Strand Palace Hotel's Gym",
#     'location': {'lat': 51.51089772999349,
#      'lng': -0.12098978003190446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51089772999349,
#        'lng': -0.12098978003190446}],
#      'distance': 609,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '544a2903498e333e2f510b01',
#     'name': 'Best Value London Hotels',
#     'location': {'address': '2 Devonshire Terrace',
#      'lat': 51.50361379162682,
#      'lng': -0.1229095458984375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50361379162682,
#        'lng': -0.1229095458984375}],
#      'distance': 527,
#      'postalCode': 'W2 3DN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['2 Devonshire Terrace',
#       'London',
#       'Greater London',
#       'W2 3DN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '53eddd5a498e6be4b226555d',
#     'name': 'Z Hotels Office',
#     'location': {'address': '45 Monmouth St',
#      'lat': 51.51287841796875,
#      'lng': -0.12716449797153473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51287841796875,
#        'lng': -0.12716449797153473}],
#      'distance': 619,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['45 Monmouth St',
#       'London',
#       'Greater London',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '5c90d1ee6f0aa2002c3de13e',
#     'name': 'Preferred Hotels & Resorts',
#     'location': {'address': '1 Wilder Walk',
#      'lat': 51.510494,
#      'lng': -0.135523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510494,
#        'lng': -0.135523}],
#      'distance': 649,
#      'postalCode': 'W1B 5AR',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Wilder Walk',
#       'London',
#       'Greater London',
#       'W1B 5AR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4f0c30ade4b0dfc434e298fe',
#     'name': 'Rocco Forte Hotels',
#     'location': {'address': '70 Jermyn St',
#      'lat': 51.507464814398034,
#      'lng': -0.13900213040823875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.507464814398034,
#        'lng': -0.13900213040823875}],
#      'distance': 786,
#      'postalCode': 'SW1Y 6NY',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['70 Jermyn St',
#       'London',
#       'Greater London',
#       'SW1Y 6NY',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4e3924cad22dea80c52cf532',
#     'name': 'Design Hotels',
#     'location': {'lat': 51.514835,
#      'lng': -0.133289,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.514835,
#        'lng': -0.133289}],
#      'distance': 923,
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London', 'Greater London', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4ff19e2fe4b02f36dc3fd764',
#     'name': 'Marriott Hotels International',
#     'location': {'address': '86 Fetter Ln',
#      'lat': 51.51716748003636,
#      'lng': -0.10915227852158585,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51716748003636,
#        'lng': -0.10915227852158585}],
#      'distance': 1686,
#      'postalCode': 'EC4A 1EN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['86 Fetter Ln',
#       'London',
#       'Greater London',
#       'EC4A 1EN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4c07ca4a88ba9521fe17e88f',
#     'name': 'JJW Hotels & Resorts',
#     'location': {'address': '6 Queen Street',
#      'lat': 51.50729340171854,
#      'lng': -0.1470869779586792,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50729340171854,
#        'lng': -0.1470869779586792}],
#      'distance': 1346,
#      'postalCode': 'W1U 2SJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['6 Queen Street',
#       'London',
#       'Greater London',
#       'W1U 2SJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4dc92accb0fbf26798c46155',
#     'name': 'Four Seasons Hotels and Resorts | London Worldwide Sales Office',
#     'location': {'address': '7 Old Park Ln',
#      'lat': 51.50409455565319,
#      'lng': -0.15005122833414028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50409455565319,
#        'lng': -0.15005122833414028}],
#      'distance': 1593,
#      'postalCode': 'W1K 1QR',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['7 Old Park Ln',
#       'London',
#       'Greater London',
#       'W1K 1QR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4b839ecdf964a5206e0b31e3',
#     'name': 'Imperial Hotel',
#     'location': {'address': '61-66 Russell Sq',
#      'lat': 51.52169709806958,
#      'lng': -0.12393501603365914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52169709806958,
#        'lng': -0.12393501603365914}],
#      'distance': 1620,
#      'postalCode': 'WC1B 5BB',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['61-66 Russell Sq',
#       'London',
#       'Greater London',
#       'WC1B 5BB',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '76180245'},
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4f869499e4b02b999b92c5b1',
#     'name': 'Hotels.com',
#     'location': {'address': '407 St John St',
#      'lat': 51.531290131002734,
#      'lng': -0.10684663327493703,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.531290131002734,
#        'lng': -0.10684663327493703}],
#      'distance': 3032,
#      'postalCode': 'EC1V 4EX',
#      'cc': 'GB',
#      'city': 'Greater London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['407 St John St',
#       'Greater London',
#       'EC1V 4EX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '73658052'},
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '521778d411d29cdeef8bcc59',
#     'name': "Megaro Hotel's Apartment",
#     'location': {'lat': 51.52960705886924,
#      'lng': -0.12357574955885715,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52960705886924,
#        'lng': -0.12357574955885715}],
#      'distance': 2496,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '5087e6cfe4b00a726d64b9d6',
#     'name': 'Aquis Hotels Ltd',
#     'location': {'address': 'Park Street 50',
#      'lat': 51.51128,
#      'lng': -0.15763,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51128,
#        'lng': -0.15763}],
#      'distance': 2123,
#      'postalCode': 'W1K 2JJ',
#      'cc': 'GB',
#      'city': 'Mayfair',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Park Street 50',
#       'Mayfair',
#       'Greater London',
#       'W1K 2JJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '5130b0d1e4b03fa96c4a9d56',
#     'name': "Leonard Hotel's bar",
#     'location': {'lat': 51.513631106784636,
#      'lng': -0.1580084996647046,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.513631106784636,
#        'lng': -0.1580084996647046}],
#      'distance': 2217,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '57076c36498eaefd5ce319da',
#     'name': 'The Z Hotel Gloucester Place',
#     'location': {'address': '51 Gloucester Pl',
#      'lat': 51.51818357322121,
#      'lng': -0.1581859588623047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51818357322121,
#        'lng': -0.1581859588623047}],
#      'distance': 2436,
#      'postalCode': 'W1U 8JF',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['51 Gloucester Pl',
#       'London',
#       'Greater London',
#       'W1U 8JF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '57c18126498e853207ce9bf3',
#     'name': 'Space NK',
#     'location': {'address': '11 Chester Street',
#      'lat': 51.5074672,
#      'lng': -0.1304918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5074672,
#        'lng': -0.1304918}],
#      'distance': 197,
#      'postalCode': 'EH3 7RF',
#      'cc': 'GB',
#      'city': 'Edinburgh',
#      'country': 'United Kingdom',
#      'formattedAddress': ['11 Chester Street',
#       'Edinburgh',
#       'EH3 7RF',
#       'United Kingdom']},
#     'categories': [{'id': '5032885091d4c4b30a586d66',
#       'name': 'Real Estate Office',
#       'pluralName': 'Real Estate Offices',
#       'shortName': 'Real Estate',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '451291286'},
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '5a5ebf09bcbf7a4d2614142c',
#     'name': 'Stowe Family Law',
#     'location': {'address': '17 Cockspur Street',
#      'lat': 51.5075531,
#      'lng': -0.13049078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5075531,
#        'lng': -0.13049078}],
#      'distance': 198,
#      'postalCode': 'SW1Y 5BL',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['17 Cockspur Street',
#       'London',
#       'Greater London',
#       'SW1Y 5BL',
#       'United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4d4bc677b9a2a143900d5723',
#     'name': 'Great Hotels of The World',
#     'location': {'address': '22 Stephenson Way',
#      'lat': 51.526282443727766,
#      'lng': -0.1358205157816709,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.526282443727766,
#        'lng': -0.1358205157816709}],
#      'distance': 2185,
#      'postalCode': 'NW1 2HD',
#      'cc': 'GB',
#      'city': 'Camden Town',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['22 Stephenson Way',
#       'Camden Town',
#       'Greater London',
#       'NW1 2HD',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4b27f875f964a520098d24e3',
#     'name': 'The Tower Hotel',
#     'location': {'address': "St Katherine's Way",
#      'lat': 51.50639159610898,
#      'lng': -0.0732226961426771,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50639159610898,
#        'lng': -0.0732226961426771}],
#      'distance': 3772,
#      'postalCode': 'E1W 1ND',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["St Katherine's Way",
#       'London',
#       'Greater London',
#       'E1W 1ND',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '535d98ba11d281035b79420b',
#     'name': 'StarStay Hotels UK',
#     'location': {'address': '190 St John St',
#      'lat': 51.52416504880453,
#      'lng': -0.10387659072875975,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52416504880453,
#        'lng': -0.10387659072875975}],
#      'distance': 2495,
#      'postalCode': 'EC1V 4PW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['190 St John St',
#       'London',
#       'Greater London',
#       'EC1V 4PW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '54520a66498eb36bf710e0ec',
#     'name': 'Choice Hotels Europe',
#     'location': {'address': '67-74 Saffron Hill',
#      'lat': 51.52197245587992,
#      'lng': -0.10734163671923459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52197245587992,
#        'lng': -0.10734163671923459}],
#      'distance': 2153,
#      'postalCode': 'EC1N 8QX',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['67-74 Saffron Hill',
#       'London',
#       'Greater London',
#       'EC1N 8QX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4fe64f83e4b04318c4140c67',
#     'name': 'The Z Hotel Victoria',
#     'location': {'address': '5 Lower Belgrave St',
#      'lat': 51.49578923785808,
#      'lng': -0.14617185751290285,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49578923785808,
#        'lng': -0.14617185751290285}],
#      'distance': 1815,
#      'postalCode': 'SW1W 0NR',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['5 Lower Belgrave St',
#       'London',
#       'Greater London',
#       'SW1W 0NR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4be52dd5d4f7c9b6b8232520',
#     'name': 'The Rathbone Hotel',
#     'location': {'address': 'Rathbone St.',
#      'lat': 51.5187071779376,
#      'lng': -0.1355567951144817,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5187071779376,
#        'lng': -0.1355567951144817}],
#      'distance': 1380,
#      'postalCode': 'W1T 1LB',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Rathbone St.',
#       'London',
#       'Greater London',
#       'W1T 1LB',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '5d0f5851e937f30023494ced',
#     'name': 'regents hotels ltd',
#     'location': {'address': '13 CHALLONER STREET',
#      'crossStreet': 'CASTLETOWN ROAD',
#      'lat': 51.48943,
#      'lng': -0.207295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.48943,
#        'lng': -0.207295}],
#      'distance': 5867,
#      'postalCode': 'W14 9HQ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['13 CHALLONER STREET (CASTLETOWN ROAD)',
#       'London',
#       'Greater London',
#       'W14 9HQ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4dc62ad5d22dafda2fb850c8',
#     'name': 'Shaftsbury Hotels Paddington',
#     'location': {'lat': 51.512115531113096,
#      'lng': -0.18624062105381742,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.512115531113096,
#        'lng': -0.18624062105381742}],
#      'distance': 4094,
#      'cc': 'GB',
#      'city': 'Paddington',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Paddington', 'Greater London', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4eb8731f30f8d0f18da0e82e',
#     'name': 'The Z Hotel Soho',
#     'location': {'address': '17 Moor St',
#      'lat': 51.51361419297205,
#      'lng': -0.1297948040922097,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51361419297205,
#        'lng': -0.1297948040922097}],
#      'distance': 716,
#      'postalCode': 'W1D 5AP',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['17 Moor St',
#       'London',
#       'Greater London',
#       'W1D 5AP',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4ac518d1f964a520e9a620e3',
#     'name': 'Haymarket Hotel Spa',
#     'location': {'address': '1 Suffolk Place',
#      'lat': 51.508238770367875,
#      'lng': -0.13151791394954457,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.508238770367875,
#        'lng': -0.13151791394954457}],
#      'distance': 286,
#      'postalCode': 'SW1Y 4BP',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Suffolk Place',
#       'London',
#       'Greater London',
#       'SW1Y 4BP',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False},
#    {'id': '4dd161dbb0fb25f6e38a1ced',
#     'name': 'Access Hotels Paddington',
#     'location': {'address': '5 Praed street',
#      'lat': 51.518815817485915,
#      'lng': -0.16906794210997367,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.518815817485915,
#        'lng': -0.16906794210997367}],
#      'distance': 3141,
#      'postalCode': 'W 2 1',
#      'cc': 'GB',
#      'city': 'Paddington',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['5 Praed street',
#       'Paddington',
#       'Greater London',
#       'W 2 1',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563145232',
#     'hasPerk': False}]}}

# %% [markdown]
# ### Parsing data into pandas dataframe

# %%
# assign relevant part of JSON to hotel
hotels = result_hotels['response']['venues']

# tranform hotels into a dataframe
london_hotels = json_normalize(hotels)
london_hotels.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '56aa371be4b08b9a8d573517', 'name': 'B...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id             location.address location.cc  \
# 0  5afb9f1b65211f002c89d942           133 Cockfosters Rd          GB
# 1  4bc1e83c2a89ef3b78daf288  Stamford Bridge Fulham Road          GB
# 2  50eb1154e4b0541e75c25274                          NaN          GB
# 3  544a2903498e333e2f510b01         2 Devonshire Terrace          GB
# 4  53eddd5a498e6be4b226555d               45 Monmouth St          GB
#
#    location.city location.country location.crossStreet  location.distance  \
# 0  Hertfordshire   United Kingdom                  NaN                 31
# 1        Chelsea   United Kingdom          Fulham Road               5165
# 2            NaN   United Kingdom                  NaN                609
# 3         London   United Kingdom                  NaN                527
# 4         London   United Kingdom                  NaN                619
#
#                            location.formattedAddress  \
# 0  [133 Cockfosters Rd, Hertfordshire, EN4 0AA, U...
# 1  [Stamford Bridge Fulham Road (Fulham Road), Ch...
# 2                                   [United Kingdom]
# 3  [2 Devonshire Terrace, London, Greater London,...
# 4  [45 Monmouth St, London, Greater London, Unite...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 51.50708638980144...     51.507086
# 1  [{'label': 'display', 'lat': 51.4810573, 'lng'...     51.481057
# 2  [{'label': 'display', 'lat': 51.51089772999349...     51.510898
# 3  [{'label': 'display', 'lat': 51.50361379162682...     51.503614
# 4  [{'label': 'display', 'lat': 51.51287841796875...     51.512878
#
#    location.lng location.postalCode  location.state  \
# 0     -0.127909             EN4 0AA   Hertfordshire
# 1     -0.189093             SW6 1HS  Greater London
# 2     -0.120990                 NaN             NaN
# 3     -0.122910              W2 3DN  Greater London
# 4     -0.127164                 NaN  Greater London
#
#                                             name    referralId venuePage.id
# 0  Global Great Hotels - Investments Real Estate  v-1563145232          NaN
# 1                  Millennium & Copthorne Hotels  v-1563145232          NaN
# 2                      Strand Palace Hotel's Gym  v-1563145232          NaN
# 3                       Best Value London Hotels  v-1563145232          NaN
# 4                                Z Hotels Office  v-1563145232          NaN

# %% [markdown]
# #### Table doesnt look nice & clean at the first glance so let's try to organize this

# %%
# keep only location columns
important_columns = ['name', 'categories'] + [col for col in london_hotels.columns if col.startswith('location.')] + ['id']
london_hotels_extract = london_hotels.loc[:, filtered_columns]

# category function
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
london_hotels_extract['categories'] = london_hotels_extract.apply(get_category_type, axis=1)

# clean column names by keeping only last term
london_hotels_extract.columns = [column.split('.')[-1] for column in london_hotels_extract.columns]

pd.DataFrame(london_hotels_extract)
london_hotels_extract
# Out:
#                                                  name  \
# 0       Global Great Hotels - Investments Real Estate
# 1                       Millennium & Copthorne Hotels
# 2                           Strand Palace Hotel's Gym
# 3                            Best Value London Hotels
# 4                                     Z Hotels Office
# 5                          Preferred Hotels & Resorts
# 6                                  Rocco Forte Hotels
# 7                                       Design Hotels
# 8                       Marriott Hotels International
# 9                                JJW Hotels & Resorts
# 10  Four Seasons Hotels and Resorts | London World...
# 11                                     Imperial Hotel
# 12                                         Hotels.com
# 13                           Megaro Hotel's Apartment
# 14                                   Aquis Hotels Ltd
# 15                                Leonard Hotel's bar
# 16                       The Z Hotel Gloucester Place
# 17                                           Space NK
# 18                                   Stowe Family Law
# 19                          Great Hotels of The World
# 20                                    The Tower Hotel
# 21                                 StarStay Hotels UK
# 22                               Choice Hotels Europe
# 23                               The Z Hotel Victoria
# 24                                 The Rathbone Hotel
# 25                                 regents hotels ltd
# 26                       Shaftsbury Hotels Paddington
# 27                                   The Z Hotel Soho
# 28                                Haymarket Hotel Spa
# 29                           Access Hotels Paddington
#
#                                   categories                      address  cc  \
# 0                            Business Center           133 Cockfosters Rd  GB
# 1                                      Hotel  Stamford Bridge Fulham Road  GB
# 2                                        Gym                          NaN  GB
# 3                                      Hotel         2 Devonshire Terrace  GB
# 4                                     Office               45 Monmouth St  GB
# 5                                     Office                1 Wilder Walk  GB
# 6                                     Office                 70 Jermyn St  GB
# 7                                     Office                          NaN  GB
# 8                                   Building                 86 Fetter Ln  GB
# 9                                     Office               6 Queen Street  GB
# 10                                    Office                7 Old Park Ln  GB
# 11                                     Hotel             61-66 Russell Sq  GB
# 12                                    Office               407 St John St  GB
# 13  Residential Building (Apartment / Condo)                          NaN  GB
# 14                                    Office               Park Street 50  GB
# 15                                 Hotel Bar                          NaN  GB
# 16                                     Hotel             51 Gloucester Pl  GB
# 17                        Real Estate Office            11 Chester Street  GB
# 18                                      None           17 Cockspur Street  GB
# 19                                    Office            22 Stephenson Way  GB
# 20                                     Hotel           St Katherine's Way  GB
# 21                                     Hotel               190 St John St  GB
# 22                                    Office           67-74 Saffron Hill  GB
# 23                                     Hotel          5 Lower Belgrave St  GB
# 24                                     Hotel                 Rathbone St.  GB
# 25                                     Hotel          13 CHALLONER STREET  GB
# 26                                     Hotel                          NaN  GB
# 27                                     Hotel                   17 Moor St  GB
# 28                                       Spa              1 Suffolk Place  GB
# 29                                     Hotel               5 Praed street  GB
#
#               city         country      crossStreet  distance  \
# 0    Hertfordshire  United Kingdom              NaN        31
# 1          Chelsea  United Kingdom      Fulham Road      5165
# 2              NaN  United Kingdom              NaN       609
# 3           London  United Kingdom              NaN       527
# 4           London  United Kingdom              NaN       619
# 5           London  United Kingdom              NaN       649
# 6           London  United Kingdom              NaN       786
# 7           London  United Kingdom              NaN       923
# 8           London  United Kingdom              NaN      1686
# 9           London  United Kingdom              NaN      1346
# 10          London  United Kingdom              NaN      1593
# 11          London  United Kingdom              NaN      1620
# 12  Greater London  United Kingdom              NaN      3032
# 13             NaN  United Kingdom              NaN      2496
# 14         Mayfair  United Kingdom              NaN      2123
# 15             NaN  United Kingdom              NaN      2217
# 16          London  United Kingdom              NaN      2436
# 17       Edinburgh  United Kingdom              NaN       197
# 18          London  United Kingdom              NaN       198
# 19     Camden Town  United Kingdom              NaN      2185
# 20          London  United Kingdom              NaN      3772
# 21          London  United Kingdom              NaN      2495
# 22          London  United Kingdom              NaN      2153
# 23          London  United Kingdom              NaN      1815
# 24          London  United Kingdom              NaN      1380
# 25          London  United Kingdom  CASTLETOWN ROAD      5867
# 26      Paddington  United Kingdom              NaN      4094
# 27          London  United Kingdom              NaN       716
# 28          London  United Kingdom              NaN       286
# 29      Paddington  United Kingdom              NaN      3141
#
#                                      formattedAddress  \
# 0   [133 Cockfosters Rd, Hertfordshire, EN4 0AA, U...
# 1   [Stamford Bridge Fulham Road (Fulham Road), Ch...
# 2                                    [United Kingdom]
# 3   [2 Devonshire Terrace, London, Greater London,...
# 4   [45 Monmouth St, London, Greater London, Unite...
# 5   [1 Wilder Walk, London, Greater London, W1B 5A...
# 6   [70 Jermyn St, London, Greater London, SW1Y 6N...
# 7            [London, Greater London, United Kingdom]
# 8   [86 Fetter Ln, London, Greater London, EC4A 1E...
# 9   [6 Queen Street, London, Greater London, W1U 2...
# 10  [7 Old Park Ln, London, Greater London, W1K 1Q...
# 11  [61-66 Russell Sq, London, Greater London, WC1...
# 12  [407 St John St, Greater London, EC1V 4EX, Uni...
# 13                                   [United Kingdom]
# 14  [Park Street 50, Mayfair, Greater London, W1K ...
# 15                                   [United Kingdom]
# 16  [51 Gloucester Pl, London, Greater London, W1U...
# 17  [11 Chester Street, Edinburgh, EH3 7RF, United...
# 18  [17 Cockspur Street, London, Greater London, S...
# 19  [22 Stephenson Way, Camden Town, Greater Londo...
# 20  [St Katherine's Way, London, Greater London, E...
# 21  [190 St John St, London, Greater London, EC1V ...
# 22  [67-74 Saffron Hill, London, Greater London, E...
# 23  [5 Lower Belgrave St, London, Greater London, ...
# 24  [Rathbone St., London, Greater London, W1T 1LB...
# 25  [13 CHALLONER STREET (CASTLETOWN ROAD), London...
# 26       [Paddington, Greater London, United Kingdom]
# 27  [17 Moor St, London, Greater London, W1D 5AP, ...
# 28  [1 Suffolk Place, London, Greater London, SW1Y...
# 29  [5 Praed street, Paddington, Greater London, W...
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 51.50708638980144...  51.507086 -0.127909
# 1   [{'label': 'display', 'lat': 51.4810573, 'lng'...  51.481057 -0.189093
# 2   [{'label': 'display', 'lat': 51.51089772999349...  51.510898 -0.120990
# 3   [{'label': 'display', 'lat': 51.50361379162682...  51.503614 -0.122910
# 4   [{'label': 'display', 'lat': 51.51287841796875...  51.512878 -0.127164
# 5   [{'label': 'display', 'lat': 51.510494, 'lng':...  51.510494 -0.135523
# 6   [{'label': 'display', 'lat': 51.50746481439803...  51.507465 -0.139002
# 7   [{'label': 'display', 'lat': 51.514835, 'lng':...  51.514835 -0.133289
# 8   [{'label': 'display', 'lat': 51.51716748003636...  51.517167 -0.109152
# 9   [{'label': 'display', 'lat': 51.50729340171854...  51.507293 -0.147087
# 10  [{'label': 'display', 'lat': 51.50409455565319...  51.504095 -0.150051
# 11  [{'label': 'display', 'lat': 51.52169709806958...  51.521697 -0.123935
# 12  [{'label': 'display', 'lat': 51.53129013100273...  51.531290 -0.106847
# 13  [{'label': 'display', 'lat': 51.52960705886924...  51.529607 -0.123576
# 14  [{'label': 'display', 'lat': 51.51128, 'lng': ...  51.511280 -0.157630
# 15  [{'label': 'display', 'lat': 51.51363110678463...  51.513631 -0.158008
# 16  [{'label': 'display', 'lat': 51.51818357322121...  51.518184 -0.158186
# 17  [{'label': 'display', 'lat': 51.5074672, 'lng'...  51.507467 -0.130492
# 18  [{'label': 'display', 'lat': 51.5075531, 'lng'...  51.507553 -0.130491
# 19  [{'label': 'display', 'lat': 51.52628244372776...  51.526282 -0.135821
# 20  [{'label': 'display', 'lat': 51.50639159610898...  51.506392 -0.073223
# 21  [{'label': 'display', 'lat': 51.52416504880453...  51.524165 -0.103877
# 22  [{'label': 'display', 'lat': 51.52197245587992...  51.521972 -0.107342
# 23  [{'label': 'display', 'lat': 51.49578923785808...  51.495789 -0.146172
# 24  [{'label': 'display', 'lat': 51.5187071779376,...  51.518707 -0.135557
# 25  [{'label': 'display', 'lat': 51.48943, 'lng': ...  51.489430 -0.207295
# 26  [{'label': 'display', 'lat': 51.51211553111309...  51.512116 -0.186241
# 27  [{'label': 'display', 'lat': 51.51361419297205...  51.513614 -0.129795
# 28  [{'label': 'display', 'lat': 51.50823877036787...  51.508239 -0.131518
# 29  [{'label': 'display', 'lat': 51.51881581748591...  51.518816 -0.169068
#
#     neighborhood postalCode           state                        id
# 0            NaN    EN4 0AA   Hertfordshire  5afb9f1b65211f002c89d942
# 1            NaN    SW6 1HS  Greater London  4bc1e83c2a89ef3b78daf288
# 2            NaN        NaN             NaN  50eb1154e4b0541e75c25274
# 3            NaN     W2 3DN  Greater London  544a2903498e333e2f510b01
# 4            NaN        NaN  Greater London  53eddd5a498e6be4b226555d
# 5            NaN    W1B 5AR  Greater London  5c90d1ee6f0aa2002c3de13e
# 6            NaN   SW1Y 6NY  Greater London  4f0c30ade4b0dfc434e298fe
# 7            NaN        NaN  Greater London  4e3924cad22dea80c52cf532
# 8            NaN   EC4A 1EN  Greater London  4ff19e2fe4b02f36dc3fd764
# 9            NaN    W1U 2SJ  Greater London  4c07ca4a88ba9521fe17e88f
# 10           NaN    W1K 1QR  Greater London  4dc92accb0fbf26798c46155
# 11           NaN   WC1B 5BB  Greater London  4b839ecdf964a5206e0b31e3
# 12           NaN   EC1V 4EX  Greater London  4f869499e4b02b999b92c5b1
# 13           NaN        NaN             NaN  521778d411d29cdeef8bcc59
# 14           NaN    W1K 2JJ  Greater London  5087e6cfe4b00a726d64b9d6
# 15           NaN        NaN             NaN  5130b0d1e4b03fa96c4a9d56
# 16           NaN    W1U 8JF  Greater London  57076c36498eaefd5ce319da
# 17           NaN    EH3 7RF             NaN  57c18126498e853207ce9bf3
# 18           NaN   SW1Y 5BL  Greater London  5a5ebf09bcbf7a4d2614142c
# 19           NaN    NW1 2HD  Greater London  4d4bc677b9a2a143900d5723
# 20           NaN    E1W 1ND  Greater London  4b27f875f964a520098d24e3
# 21           NaN   EC1V 4PW  Greater London  535d98ba11d281035b79420b
# 22           NaN   EC1N 8QX  Greater London  54520a66498eb36bf710e0ec
# 23           NaN   SW1W 0NR  Greater London  4fe64f83e4b04318c4140c67
# 24           NaN    W1T 1LB  Greater London  4be52dd5d4f7c9b6b8232520
# 25           NaN    W14 9HQ  Greater London  5d0f5851e937f30023494ced
# 26           NaN        NaN  Greater London  4dc62ad5d22dafda2fb850c8
# 27           NaN    W1D 5AP  Greater London  4eb8731f30f8d0f18da0e82e
# 28           NaN   SW1Y 4BP  Greater London  4ac518d1f964a520e9a620e3
# 29           NaN      W 2 1  Greater London  4dd161dbb0fb25f6e38a1ced

# %% [markdown]
# #### Foursquare application sometimes returns incorrect data, as seen in 'category' column. 'Office, Building, Spa' is actually a hotel, so we need to recategorize them and drop all other values

# %%
london_hotels_extract = london_hotels_extract[london_hotels_extract.categories.isin(['Hotel', 'Office','Building','Spa'])]
london_hotels_extract.categories = 'Hotel'
london_hotels_extract.reset_index(drop=True, inplace=True)
london_hotels_extract
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#                                                  name categories  \
# 0                       Millennium & Copthorne Hotels      Hotel
# 1                            Best Value London Hotels      Hotel
# 2                                     Z Hotels Office      Hotel
# 3                          Preferred Hotels & Resorts      Hotel
# 4                                  Rocco Forte Hotels      Hotel
# 5                                       Design Hotels      Hotel
# 6                       Marriott Hotels International      Hotel
# 7                                JJW Hotels & Resorts      Hotel
# 8   Four Seasons Hotels and Resorts | London World...      Hotel
# 9                                      Imperial Hotel      Hotel
# 10                                         Hotels.com      Hotel
# 11                                   Aquis Hotels Ltd      Hotel
# 12                       The Z Hotel Gloucester Place      Hotel
# 13                          Great Hotels of The World      Hotel
# 14                                    The Tower Hotel      Hotel
# 15                                 StarStay Hotels UK      Hotel
# 16                               Choice Hotels Europe      Hotel
# 17                               The Z Hotel Victoria      Hotel
# 18                                 The Rathbone Hotel      Hotel
# 19                                 regents hotels ltd      Hotel
# 20                       Shaftsbury Hotels Paddington      Hotel
# 21                                   The Z Hotel Soho      Hotel
# 22                                Haymarket Hotel Spa      Hotel
# 23                           Access Hotels Paddington      Hotel
#
#                         address  cc            city         country  \
# 0   Stamford Bridge Fulham Road  GB         Chelsea  United Kingdom
# 1          2 Devonshire Terrace  GB          London  United Kingdom
# 2                45 Monmouth St  GB          London  United Kingdom
# 3                 1 Wilder Walk  GB          London  United Kingdom
# 4                  70 Jermyn St  GB          London  United Kingdom
# 5                           NaN  GB          London  United Kingdom
# 6                  86 Fetter Ln  GB          London  United Kingdom
# 7                6 Queen Street  GB          London  United Kingdom
# 8                 7 Old Park Ln  GB          London  United Kingdom
# 9              61-66 Russell Sq  GB          London  United Kingdom
# 10               407 St John St  GB  Greater London  United Kingdom
# 11               Park Street 50  GB         Mayfair  United Kingdom
# 12             51 Gloucester Pl  GB          London  United Kingdom
# 13            22 Stephenson Way  GB     Camden Town  United Kingdom
# 14           St Katherine's Way  GB          London  United Kingdom
# 15               190 St John St  GB          London  United Kingdom
# 16           67-74 Saffron Hill  GB          London  United Kingdom
# 17          5 Lower Belgrave St  GB          London  United Kingdom
# 18                 Rathbone St.  GB          London  United Kingdom
# 19          13 CHALLONER STREET  GB          London  United Kingdom
# 20                          NaN  GB      Paddington  United Kingdom
# 21                   17 Moor St  GB          London  United Kingdom
# 22              1 Suffolk Place  GB          London  United Kingdom
# 23               5 Praed street  GB      Paddington  United Kingdom
#
#         crossStreet  distance  \
# 0       Fulham Road      5165
# 1               NaN       527
# 2               NaN       619
# 3               NaN       649
# 4               NaN       786
# 5               NaN       923
# 6               NaN      1686
# 7               NaN      1346
# 8               NaN      1593
# 9               NaN      1620
# 10              NaN      3032
# 11              NaN      2123
# 12              NaN      2436
# 13              NaN      2185
# 14              NaN      3772
# 15              NaN      2495
# 16              NaN      2153
# 17              NaN      1815
# 18              NaN      1380
# 19  CASTLETOWN ROAD      5867
# 20              NaN      4094
# 21              NaN       716
# 22              NaN       286
# 23              NaN      3141
#
#                                      formattedAddress  \
# 0   [Stamford Bridge Fulham Road (Fulham Road), Ch...
# 1   [2 Devonshire Terrace, London, Greater London,...
# 2   [45 Monmouth St, London, Greater London, Unite...
# 3   [1 Wilder Walk, London, Greater London, W1B 5A...
# 4   [70 Jermyn St, London, Greater London, SW1Y 6N...
# 5            [London, Greater London, United Kingdom]
# 6   [86 Fetter Ln, London, Greater London, EC4A 1E...
# 7   [6 Queen Street, London, Greater London, W1U 2...
# 8   [7 Old Park Ln, London, Greater London, W1K 1Q...
# 9   [61-66 Russell Sq, London, Greater London, WC1...
# 10  [407 St John St, Greater London, EC1V 4EX, Uni...
# 11  [Park Street 50, Mayfair, Greater London, W1K ...
# 12  [51 Gloucester Pl, London, Greater London, W1U...
# 13  [22 Stephenson Way, Camden Town, Greater Londo...
# 14  [St Katherine's Way, London, Greater London, E...
# 15  [190 St John St, London, Greater London, EC1V ...
# 16  [67-74 Saffron Hill, London, Greater London, E...
# 17  [5 Lower Belgrave St, London, Greater London, ...
# 18  [Rathbone St., London, Greater London, W1T 1LB...
# 19  [13 CHALLONER STREET (CASTLETOWN ROAD), London...
# 20       [Paddington, Greater London, United Kingdom]
# 21  [17 Moor St, London, Greater London, W1D 5AP, ...
# 22  [1 Suffolk Place, London, Greater London, SW1Y...
# 23  [5 Praed street, Paddington, Greater London, W...
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 51.4810573, 'lng'...  51.481057 -0.189093
# 1   [{'label': 'display', 'lat': 51.50361379162682...  51.503614 -0.122910
# 2   [{'label': 'display', 'lat': 51.51287841796875...  51.512878 -0.127164
# 3   [{'label': 'display', 'lat': 51.510494, 'lng':...  51.510494 -0.135523
# 4   [{'label': 'display', 'lat': 51.50746481439803...  51.507465 -0.139002
# 5   [{'label': 'display', 'lat': 51.514835, 'lng':...  51.514835 -0.133289
# 6   [{'label': 'display', 'lat': 51.51716748003636...  51.517167 -0.109152
# 7   [{'label': 'display', 'lat': 51.50729340171854...  51.507293 -0.147087
# 8   [{'label': 'display', 'lat': 51.50409455565319...  51.504095 -0.150051
# 9   [{'label': 'display', 'lat': 51.52169709806958...  51.521697 -0.123935
# 10  [{'label': 'display', 'lat': 51.53129013100273...  51.531290 -0.106847
# 11  [{'label': 'display', 'lat': 51.51128, 'lng': ...  51.511280 -0.157630
# 12  [{'label': 'display', 'lat': 51.51818357322121...  51.518184 -0.158186
# 13  [{'label': 'display', 'lat': 51.52628244372776...  51.526282 -0.135821
# 14  [{'label': 'display', 'lat': 51.50639159610898...  51.506392 -0.073223
# 15  [{'label': 'display', 'lat': 51.52416504880453...  51.524165 -0.103877
# 16  [{'label': 'display', 'lat': 51.52197245587992...  51.521972 -0.107342
# 17  [{'label': 'display', 'lat': 51.49578923785808...  51.495789 -0.146172
# 18  [{'label': 'display', 'lat': 51.5187071779376,...  51.518707 -0.135557
# 19  [{'label': 'display', 'lat': 51.48943, 'lng': ...  51.489430 -0.207295
# 20  [{'label': 'display', 'lat': 51.51211553111309...  51.512116 -0.186241
# 21  [{'label': 'display', 'lat': 51.51361419297205...  51.513614 -0.129795
# 22  [{'label': 'display', 'lat': 51.50823877036787...  51.508239 -0.131518
# 23  [{'label': 'display', 'lat': 51.51881581748591...  51.518816 -0.169068
#
#     neighborhood postalCode           state                        id
# 0            NaN    SW6 1HS  Greater London  4bc1e83c2a89ef3b78daf288
# 1            NaN     W2 3DN  Greater London  544a2903498e333e2f510b01
# 2            NaN        NaN  Greater London  53eddd5a498e6be4b226555d
# 3            NaN    W1B 5AR  Greater London  5c90d1ee6f0aa2002c3de13e
# 4            NaN   SW1Y 6NY  Greater London  4f0c30ade4b0dfc434e298fe
# 5            NaN        NaN  Greater London  4e3924cad22dea80c52cf532
# 6            NaN   EC4A 1EN  Greater London  4ff19e2fe4b02f36dc3fd764
# 7            NaN    W1U 2SJ  Greater London  4c07ca4a88ba9521fe17e88f
# 8            NaN    W1K 1QR  Greater London  4dc92accb0fbf26798c46155
# 9            NaN   WC1B 5BB  Greater London  4b839ecdf964a5206e0b31e3
# 10           NaN   EC1V 4EX  Greater London  4f869499e4b02b999b92c5b1
# 11           NaN    W1K 2JJ  Greater London  5087e6cfe4b00a726d64b9d6
# 12           NaN    W1U 8JF  Greater London  57076c36498eaefd5ce319da
# 13           NaN    NW1 2HD  Greater London  4d4bc677b9a2a143900d5723
# 14           NaN    E1W 1ND  Greater London  4b27f875f964a520098d24e3
# 15           NaN   EC1V 4PW  Greater London  535d98ba11d281035b79420b
# 16           NaN   EC1N 8QX  Greater London  54520a66498eb36bf710e0ec
# 17           NaN   SW1W 0NR  Greater London  4fe64f83e4b04318c4140c67
# 18           NaN    W1T 1LB  Greater London  4be52dd5d4f7c9b6b8232520
# 19           NaN    W14 9HQ  Greater London  5d0f5851e937f30023494ced
# 20           NaN        NaN  Greater London  4dc62ad5d22dafda2fb850c8
# 21           NaN    W1D 5AP  Greater London  4eb8731f30f8d0f18da0e82e
# 22           NaN   SW1Y 4BP  Greater London  4ac518d1f964a520e9a620e3
# 23           NaN      W 2 1  Greater London  4dd161dbb0fb25f6e38a1ced

# %% [markdown]
# #### Still there are columns that are not needed for the further evaluation (eg. 'crossStreet'). These should be deleted

# %%
london_hotels_extract.drop(['crossStreet', 'labeledLatLngs', 'postalCode', 'state', 'country', 'city',], axis=1, inplace=True)
london_hotels_extract
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#                                                  name categories  \
# 0                       Millennium & Copthorne Hotels      Hotel
# 1                            Best Value London Hotels      Hotel
# 2                                     Z Hotels Office      Hotel
# 3                          Preferred Hotels & Resorts      Hotel
# 4                                  Rocco Forte Hotels      Hotel
# 5                                       Design Hotels      Hotel
# 6                       Marriott Hotels International      Hotel
# 7                                JJW Hotels & Resorts      Hotel
# 8   Four Seasons Hotels and Resorts | London World...      Hotel
# 9                                      Imperial Hotel      Hotel
# 10                                         Hotels.com      Hotel
# 11                                   Aquis Hotels Ltd      Hotel
# 12                       The Z Hotel Gloucester Place      Hotel
# 13                          Great Hotels of The World      Hotel
# 14                                    The Tower Hotel      Hotel
# 15                                 StarStay Hotels UK      Hotel
# 16                               Choice Hotels Europe      Hotel
# 17                               The Z Hotel Victoria      Hotel
# 18                                 The Rathbone Hotel      Hotel
# 19                                 regents hotels ltd      Hotel
# 20                       Shaftsbury Hotels Paddington      Hotel
# 21                                   The Z Hotel Soho      Hotel
# 22                                Haymarket Hotel Spa      Hotel
# 23                           Access Hotels Paddington      Hotel
#
#                         address  cc  distance  \
# 0   Stamford Bridge Fulham Road  GB      5165
# 1          2 Devonshire Terrace  GB       527
# 2                45 Monmouth St  GB       619
# 3                 1 Wilder Walk  GB       649
# 4                  70 Jermyn St  GB       786
# 5                           NaN  GB       923
# 6                  86 Fetter Ln  GB      1686
# 7                6 Queen Street  GB      1346
# 8                 7 Old Park Ln  GB      1593
# 9              61-66 Russell Sq  GB      1620
# 10               407 St John St  GB      3032
# 11               Park Street 50  GB      2123
# 12             51 Gloucester Pl  GB      2436
# 13            22 Stephenson Way  GB      2185
# 14           St Katherine's Way  GB      3772
# 15               190 St John St  GB      2495
# 16           67-74 Saffron Hill  GB      2153
# 17          5 Lower Belgrave St  GB      1815
# 18                 Rathbone St.  GB      1380
# 19          13 CHALLONER STREET  GB      5867
# 20                          NaN  GB      4094
# 21                   17 Moor St  GB       716
# 22              1 Suffolk Place  GB       286
# 23               5 Praed street  GB      3141
#
#                                      formattedAddress        lat       lng  \
# 0   [Stamford Bridge Fulham Road (Fulham Road), Ch...  51.481057 -0.189093
# 1   [2 Devonshire Terrace, London, Greater London,...  51.503614 -0.122910
# 2   [45 Monmouth St, London, Greater London, Unite...  51.512878 -0.127164
# 3   [1 Wilder Walk, London, Greater London, W1B 5A...  51.510494 -0.135523
# 4   [70 Jermyn St, London, Greater London, SW1Y 6N...  51.507465 -0.139002
# 5            [London, Greater London, United Kingdom]  51.514835 -0.133289
# 6   [86 Fetter Ln, London, Greater London, EC4A 1E...  51.517167 -0.109152
# 7   [6 Queen Street, London, Greater London, W1U 2...  51.507293 -0.147087
# 8   [7 Old Park Ln, London, Greater London, W1K 1Q...  51.504095 -0.150051
# 9   [61-66 Russell Sq, London, Greater London, WC1...  51.521697 -0.123935
# 10  [407 St John St, Greater London, EC1V 4EX, Uni...  51.531290 -0.106847
# 11  [Park Street 50, Mayfair, Greater London, W1K ...  51.511280 -0.157630
# 12  [51 Gloucester Pl, London, Greater London, W1U...  51.518184 -0.158186
# 13  [22 Stephenson Way, Camden Town, Greater Londo...  51.526282 -0.135821
# 14  [St Katherine's Way, London, Greater London, E...  51.506392 -0.073223
# 15  [190 St John St, London, Greater London, EC1V ...  51.524165 -0.103877
# 16  [67-74 Saffron Hill, London, Greater London, E...  51.521972 -0.107342
# 17  [5 Lower Belgrave St, London, Greater London, ...  51.495789 -0.146172
# 18  [Rathbone St., London, Greater London, W1T 1LB...  51.518707 -0.135557
# 19  [13 CHALLONER STREET (CASTLETOWN ROAD), London...  51.489430 -0.207295
# 20       [Paddington, Greater London, United Kingdom]  51.512116 -0.186241
# 21  [17 Moor St, London, Greater London, W1D 5AP, ...  51.513614 -0.129795
# 22  [1 Suffolk Place, London, Greater London, SW1Y...  51.508239 -0.131518
# 23  [5 Praed street, Paddington, Greater London, W...  51.518816 -0.169068
#
#     neighborhood                        id
# 0            NaN  4bc1e83c2a89ef3b78daf288
# 1            NaN  544a2903498e333e2f510b01
# 2            NaN  53eddd5a498e6be4b226555d
# 3            NaN  5c90d1ee6f0aa2002c3de13e
# 4            NaN  4f0c30ade4b0dfc434e298fe
# 5            NaN  4e3924cad22dea80c52cf532
# 6            NaN  4ff19e2fe4b02f36dc3fd764
# 7            NaN  4c07ca4a88ba9521fe17e88f
# 8            NaN  4dc92accb0fbf26798c46155
# 9            NaN  4b839ecdf964a5206e0b31e3
# 10           NaN  4f869499e4b02b999b92c5b1
# 11           NaN  5087e6cfe4b00a726d64b9d6
# 12           NaN  57076c36498eaefd5ce319da
# 13           NaN  4d4bc677b9a2a143900d5723
# 14           NaN  4b27f875f964a520098d24e3
# 15           NaN  535d98ba11d281035b79420b
# 16           NaN  54520a66498eb36bf710e0ec
# 17           NaN  4fe64f83e4b04318c4140c67
# 18           NaN  4be52dd5d4f7c9b6b8232520
# 19           NaN  5d0f5851e937f30023494ced
# 20           NaN  4dc62ad5d22dafda2fb850c8
# 21           NaN  4eb8731f30f8d0f18da0e82e
# 22           NaN  4ac518d1f964a520e9a620e3
# 23           NaN  4dd161dbb0fb25f6e38a1ced

# %% [markdown]
# ## Given we have nice & clean table, we can visualize the results

# %%
london_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# London
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='London',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(london_map)

# Hotels
for lat, lng, label in zip(london_hotels_extract.lat, london_hotels_extract.lng, london_hotels_extract.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(london_map)

london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ***

# %% [markdown]
# # Methodology

# %% [markdown]
# ## The whole project is about to find the best hotel
#
# ### We have collected & cleaned & visualized data, now its the time for the next steps
# ### As discussed, hotels are graded using their online rating and nearby venues, so now we will try to obtain rating using Foursquare API for all the hotels - we will loop through API database to get everything we need. Once completed it will allow us to point best 5 hotels
#
# ### Once best hotels are pointed, we again use Foursquare API to find the venues in 1km range from the hotel - this is the second requirement for our decision process. When all data is in place, we are going to use k-means clustering method for venue categorization and final data visualization on a London map

# %% [markdown]
# ***

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### First step in this section is to obtain ratings using Foursquare API. Using Hotel ID we are going to loop the database and fill the lists with the ratings

# %%
london_ratings = pd.DataFrame()
rating_list = pd.Series([]) 
id_list = pd.Series([]) 
for i in range(len(london_hotels_extract.id)):
    hotel_id = london_hotels_extract.id[i] # ID of Hotels
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(hotel_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    #Let's Check for Ratings, If Available then store it and if not, then store 0
    try:
        rating_list[i] = result['response']['venue']['rating'] 
        id_list[i] = london_hotels_extract.id[i]
    except:
        rating_list[i] = 0
        id_list[i] = london_hotels_extract.id[i]
         
        
london_ratings.insert(0, "ID", id_list, allow_duplicates=True)
london_ratings.insert(1, "Ratings", rating_list, allow_duplicates=True)
london_ratings
# Out:
#                           ID  Ratings
# 0   4bc1e83c2a89ef3b78daf288      6.4
# 1   544a2903498e333e2f510b01      0.0
# 2   53eddd5a498e6be4b226555d      0.0
# 3   5c90d1ee6f0aa2002c3de13e      0.0
# 4   4f0c30ade4b0dfc434e298fe      0.0
# 5   4e3924cad22dea80c52cf532      0.0
# 6   4ff19e2fe4b02f36dc3fd764      0.0
# 7   4c07ca4a88ba9521fe17e88f      0.0
# 8   4dc92accb0fbf26798c46155      0.0
# 9   4b839ecdf964a5206e0b31e3      4.8
# 10  4f869499e4b02b999b92c5b1      0.0
# 11  5087e6cfe4b00a726d64b9d6      0.0
# 12  57076c36498eaefd5ce319da      8.8
# 13  4d4bc677b9a2a143900d5723      0.0
# 14  4b27f875f964a520098d24e3      7.6
# 15  535d98ba11d281035b79420b      0.0
# 16  54520a66498eb36bf710e0ec      0.0
# 17  4fe64f83e4b04318c4140c67      7.4
# 18  4be52dd5d4f7c9b6b8232520      5.4
# 19  5d0f5851e937f30023494ced      0.0
# 20  4dc62ad5d22dafda2fb850c8      0.0
# 21  4eb8731f30f8d0f18da0e82e      5.8
# 22  4ac518d1f964a520e9a620e3      0.0
# 23  4dd161dbb0fb25f6e38a1ced      0.0

# %% [markdown]
# ### Adding ratings to the Hotels table

# %%
london_ratings.columns = ['id', 'Ratings']
london_hotels_extract = pd.merge(london_hotels_extract,
                 london_ratings,
                 on='id')
london_hotels_extract
# Out:
#                                                  name categories  \
# 0                       Millennium & Copthorne Hotels      Hotel
# 1                            Best Value London Hotels      Hotel
# 2                                     Z Hotels Office      Hotel
# 3                          Preferred Hotels & Resorts      Hotel
# 4                                  Rocco Forte Hotels      Hotel
# 5                                       Design Hotels      Hotel
# 6                       Marriott Hotels International      Hotel
# 7                                JJW Hotels & Resorts      Hotel
# 8   Four Seasons Hotels and Resorts | London World...      Hotel
# 9                                      Imperial Hotel      Hotel
# 10                                         Hotels.com      Hotel
# 11                                   Aquis Hotels Ltd      Hotel
# 12                       The Z Hotel Gloucester Place      Hotel
# 13                          Great Hotels of The World      Hotel
# 14                                    The Tower Hotel      Hotel
# 15                                 StarStay Hotels UK      Hotel
# 16                               Choice Hotels Europe      Hotel
# 17                               The Z Hotel Victoria      Hotel
# 18                                 The Rathbone Hotel      Hotel
# 19                                 regents hotels ltd      Hotel
# 20                       Shaftsbury Hotels Paddington      Hotel
# 21                                   The Z Hotel Soho      Hotel
# 22                                Haymarket Hotel Spa      Hotel
# 23                           Access Hotels Paddington      Hotel
#
#                         address  cc  distance  \
# 0   Stamford Bridge Fulham Road  GB      5165
# 1          2 Devonshire Terrace  GB       527
# 2                45 Monmouth St  GB       619
# 3                 1 Wilder Walk  GB       649
# 4                  70 Jermyn St  GB       786
# 5                           NaN  GB       923
# 6                  86 Fetter Ln  GB      1686
# 7                6 Queen Street  GB      1346
# 8                 7 Old Park Ln  GB      1593
# 9              61-66 Russell Sq  GB      1620
# 10               407 St John St  GB      3032
# 11               Park Street 50  GB      2123
# 12             51 Gloucester Pl  GB      2436
# 13            22 Stephenson Way  GB      2185
# 14           St Katherine's Way  GB      3772
# 15               190 St John St  GB      2495
# 16           67-74 Saffron Hill  GB      2153
# 17          5 Lower Belgrave St  GB      1815
# 18                 Rathbone St.  GB      1380
# 19          13 CHALLONER STREET  GB      5867
# 20                          NaN  GB      4094
# 21                   17 Moor St  GB       716
# 22              1 Suffolk Place  GB       286
# 23               5 Praed street  GB      3141
#
#                                      formattedAddress        lat       lng  \
# 0   [Stamford Bridge Fulham Road (Fulham Road), Ch...  51.481057 -0.189093
# 1   [2 Devonshire Terrace, London, Greater London,...  51.503614 -0.122910
# 2   [45 Monmouth St, London, Greater London, Unite...  51.512878 -0.127164
# 3   [1 Wilder Walk, London, Greater London, W1B 5A...  51.510494 -0.135523
# 4   [70 Jermyn St, London, Greater London, SW1Y 6N...  51.507465 -0.139002
# 5            [London, Greater London, United Kingdom]  51.514835 -0.133289
# 6   [86 Fetter Ln, London, Greater London, EC4A 1E...  51.517167 -0.109152
# 7   [6 Queen Street, London, Greater London, W1U 2...  51.507293 -0.147087
# 8   [7 Old Park Ln, London, Greater London, W1K 1Q...  51.504095 -0.150051
# 9   [61-66 Russell Sq, London, Greater London, WC1...  51.521697 -0.123935
# 10  [407 St John St, Greater London, EC1V 4EX, Uni...  51.531290 -0.106847
# 11  [Park Street 50, Mayfair, Greater London, W1K ...  51.511280 -0.157630
# 12  [51 Gloucester Pl, London, Greater London, W1U...  51.518184 -0.158186
# 13  [22 Stephenson Way, Camden Town, Greater Londo...  51.526282 -0.135821
# 14  [St Katherine's Way, London, Greater London, E...  51.506392 -0.073223
# 15  [190 St John St, London, Greater London, EC1V ...  51.524165 -0.103877
# 16  [67-74 Saffron Hill, London, Greater London, E...  51.521972 -0.107342
# 17  [5 Lower Belgrave St, London, Greater London, ...  51.495789 -0.146172
# 18  [Rathbone St., London, Greater London, W1T 1LB...  51.518707 -0.135557
# 19  [13 CHALLONER STREET (CASTLETOWN ROAD), London...  51.489430 -0.207295
# 20       [Paddington, Greater London, United Kingdom]  51.512116 -0.186241
# 21  [17 Moor St, London, Greater London, W1D 5AP, ...  51.513614 -0.129795
# 22  [1 Suffolk Place, London, Greater London, SW1Y...  51.508239 -0.131518
# 23  [5 Praed street, Paddington, Greater London, W...  51.518816 -0.169068
#
#     neighborhood                        id  Ratings
# 0            NaN  4bc1e83c2a89ef3b78daf288      6.4
# 1            NaN  544a2903498e333e2f510b01      0.0
# 2            NaN  53eddd5a498e6be4b226555d      0.0
# 3            NaN  5c90d1ee6f0aa2002c3de13e      0.0
# 4            NaN  4f0c30ade4b0dfc434e298fe      0.0
# 5            NaN  4e3924cad22dea80c52cf532      0.0
# 6            NaN  4ff19e2fe4b02f36dc3fd764      0.0
# 7            NaN  4c07ca4a88ba9521fe17e88f      0.0
# 8            NaN  4dc92accb0fbf26798c46155      0.0
# 9            NaN  4b839ecdf964a5206e0b31e3      4.8
# 10           NaN  4f869499e4b02b999b92c5b1      0.0
# 11           NaN  5087e6cfe4b00a726d64b9d6      0.0
# 12           NaN  57076c36498eaefd5ce319da      8.8
# 13           NaN  4d4bc677b9a2a143900d5723      0.0
# 14           NaN  4b27f875f964a520098d24e3      7.6
# 15           NaN  535d98ba11d281035b79420b      0.0
# 16           NaN  54520a66498eb36bf710e0ec      0.0
# 17           NaN  4fe64f83e4b04318c4140c67      7.4
# 18           NaN  4be52dd5d4f7c9b6b8232520      5.4
# 19           NaN  5d0f5851e937f30023494ced      0.0
# 20           NaN  4dc62ad5d22dafda2fb850c8      0.0
# 21           NaN  4eb8731f30f8d0f18da0e82e      5.8
# 22           NaN  4ac518d1f964a520e9a620e3      0.0
# 23           NaN  4dd161dbb0fb25f6e38a1ced      0.0

# %% [markdown]
# ### As we see, many hotels dont have the ratings in place - let's remove them

# %%
london_hotels_extract = london_hotels_extract.set_index("Ratings")
london_hotels_extract = london_hotels_extract.drop(0.0, axis=0)
london_hotels_extract
# Out:
#                                   name categories  \
# Ratings
# 6.4      Millennium & Copthorne Hotels      Hotel
# 4.8                     Imperial Hotel      Hotel
# 8.8       The Z Hotel Gloucester Place      Hotel
# 7.6                    The Tower Hotel      Hotel
# 7.4               The Z Hotel Victoria      Hotel
# 5.4                 The Rathbone Hotel      Hotel
# 5.8                   The Z Hotel Soho      Hotel
#
#                              address  cc  distance  \
# Ratings
# 6.4      Stamford Bridge Fulham Road  GB      5165
# 4.8                 61-66 Russell Sq  GB      1620
# 8.8                 51 Gloucester Pl  GB      2436
# 7.6               St Katherine's Way  GB      3772
# 7.4              5 Lower Belgrave St  GB      1815
# 5.4                     Rathbone St.  GB      1380
# 5.8                       17 Moor St  GB       716
#
#                                           formattedAddress        lat  \
# Ratings
# 6.4      [Stamford Bridge Fulham Road (Fulham Road), Ch...  51.481057
# 4.8      [61-66 Russell Sq, London, Greater London, WC1...  51.521697
# 8.8      [51 Gloucester Pl, London, Greater London, W1U...  51.518184
# 7.6      [St Katherine's Way, London, Greater London, E...  51.506392
# 7.4      [5 Lower Belgrave St, London, Greater London, ...  51.495789
# 5.4      [Rathbone St., London, Greater London, W1T 1LB...  51.518707
# 5.8      [17 Moor St, London, Greater London, W1D 5AP, ...  51.513614
#
#               lng  neighborhood                        id
# Ratings
# 6.4     -0.189093           NaN  4bc1e83c2a89ef3b78daf288
# 4.8     -0.123935           NaN  4b839ecdf964a5206e0b31e3
# 8.8     -0.158186           NaN  57076c36498eaefd5ce319da
# 7.6     -0.073223           NaN  4b27f875f964a520098d24e3
# 7.4     -0.146172           NaN  4fe64f83e4b04318c4140c67
# 5.4     -0.135557           NaN  4be52dd5d4f7c9b6b8232520
# 5.8     -0.129795           NaN  4eb8731f30f8d0f18da0e82e

# %% [markdown]
# ### Table is in place, so now we can take the top 5 hotels based on a rating

# %%
london_hotels_extract.sort_values('Ratings', ascending=False, inplace=True) 
london_hotels_extract = london_hotels_extract.head(5)
london_hotels_extract
# Out:
#                                   name categories  \
# Ratings
# 8.8       The Z Hotel Gloucester Place      Hotel
# 7.6                    The Tower Hotel      Hotel
# 7.4               The Z Hotel Victoria      Hotel
# 6.4      Millennium & Copthorne Hotels      Hotel
# 5.8                   The Z Hotel Soho      Hotel
#
#                              address  cc  distance  \
# Ratings
# 8.8                 51 Gloucester Pl  GB      2436
# 7.6               St Katherine's Way  GB      3772
# 7.4              5 Lower Belgrave St  GB      1815
# 6.4      Stamford Bridge Fulham Road  GB      5165
# 5.8                       17 Moor St  GB       716
#
#                                           formattedAddress        lat  \
# Ratings
# 8.8      [51 Gloucester Pl, London, Greater London, W1U...  51.518184
# 7.6      [St Katherine's Way, London, Greater London, E...  51.506392
# 7.4      [5 Lower Belgrave St, London, Greater London, ...  51.495789
# 6.4      [Stamford Bridge Fulham Road (Fulham Road), Ch...  51.481057
# 5.8      [17 Moor St, London, Greater London, W1D 5AP, ...  51.513614
#
#               lng  neighborhood                        id
# Ratings
# 8.8     -0.158186           NaN  57076c36498eaefd5ce319da
# 7.6     -0.073223           NaN  4b27f875f964a520098d24e3
# 7.4     -0.146172           NaN  4fe64f83e4b04318c4140c67
# 6.4     -0.189093           NaN  4bc1e83c2a89ef3b78daf288
# 5.8     -0.129795           NaN  4eb8731f30f8d0f18da0e82e

# %% [markdown]
# #### Column 'neighbourhood' at the end doesnt provide any useful information as well so we can delete this as well

# %%
london_hotels_extract.drop(['neighborhood',], axis=1, inplace=True)
london_hotels_extract
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#                                   name categories  \
# Ratings
# 8.8       The Z Hotel Gloucester Place      Hotel
# 7.6                    The Tower Hotel      Hotel
# 7.4               The Z Hotel Victoria      Hotel
# 6.4      Millennium & Copthorne Hotels      Hotel
# 5.8                   The Z Hotel Soho      Hotel
#
#                              address  cc  distance  \
# Ratings
# 8.8                 51 Gloucester Pl  GB      2436
# 7.6               St Katherine's Way  GB      3772
# 7.4              5 Lower Belgrave St  GB      1815
# 6.4      Stamford Bridge Fulham Road  GB      5165
# 5.8                       17 Moor St  GB       716
#
#                                           formattedAddress        lat  \
# Ratings
# 8.8      [51 Gloucester Pl, London, Greater London, W1U...  51.518184
# 7.6      [St Katherine's Way, London, Greater London, E...  51.506392
# 7.4      [5 Lower Belgrave St, London, Greater London, ...  51.495789
# 6.4      [Stamford Bridge Fulham Road (Fulham Road), Ch...  51.481057
# 5.8      [17 Moor St, London, Greater London, W1D 5AP, ...  51.513614
#
#               lng                        id
# Ratings
# 8.8     -0.158186  57076c36498eaefd5ce319da
# 7.6     -0.073223  4b27f875f964a520098d24e3
# 7.4     -0.146172  4fe64f83e4b04318c4140c67
# 6.4     -0.189093  4bc1e83c2a89ef3b78daf288
# 5.8     -0.129795  4eb8731f30f8d0f18da0e82e

# %% [markdown]
# # Last point in data capture - Searching for venues for each hotel

# %% [markdown]
# ### We have managed to get top 5 hotels in London as per table above - using their geological position we are able to get the venues that are placed in 1 km range (using Foursquare API)

# %%
d = {}
for i in range(5): #5 as this we have 5 hotels
    d[i] = pd.DataFrame()
    lat = london_hotels_extract['lat'].iloc[i]
    lng = london_hotels_extract['lng'].iloc[i]
    LIMIT=300
    radius = 1000
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&near={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, lng, VERSION, radius, LIMIT)
    results = requests.get(url).json()
    items = results['response']['groups'][0]['items']
    dataframe = json_normalize(items)
      
    # filter columns
    valid_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
    df = dataframe.loc[:, valid_columns]
    
    # filter the category for each row
    df['venue.categories'] = df.apply(get_category_type, axis=1)
    
    # clean columns
    df.columns = [col.split('.')[-1] for col in df.columns]
    
    d[i] = df

# %% [markdown]
# #### We should have all venues for these 5 hotels, so let's organize those tables

# %%
london_hotel1 = d[0]
london_hotel2 = d[1]
london_hotel3 = d[2]
london_hotel4 = d[3]
london_hotel5 = d[4]

# %% [markdown]
# #### As example let's look at venues table for 'The Z Hotel Gloucester Place'.

# %%
london_hotel1.head()
# Out:
#                            name                  categories           address  \
# 0              DW Fitness First        Gym / Fitness Center       55 Baker St
# 1  The Z Hotel Gloucester Place                       Hotel  51 Gloucester Pl
# 2                      Carousel                  Restaurant   71 Blandford St
# 3               JOE & THE JUICE                   Juice Bar    7 Baker Street
# 4            Chiltern Firehouse  Modern European Restaurant     1 Chiltern St
#
#    cc    city         country crossStreet  \
# 0  GB  London  United Kingdom         NaN
# 1  GB  London  United Kingdom         NaN
# 2  GB  London  United Kingdom         NaN
# 3  GB  London  United Kingdom         NaN
# 4  GB  London  United Kingdom         NaN
#
#                                     formattedAddress  \
# 0  [55 Baker St, London, Greater London, W1U 8EU,...
# 1  [51 Gloucester Pl, London, Greater London, W1U...
# 2  [71 Blandford St, London, Greater London, W1U ...
# 3  [7 Baker Street, London, Greater London, W1U 3...
# 4  [1 Chiltern St, London, Greater London, W1U 7P...
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 51.51879825605098...  51.518798 -0.156122
# 1  [{'label': 'display', 'lat': 51.51818357322121...  51.518184 -0.158186
# 2  [{'label': 'display', 'lat': 51.51799163692346...  51.517992 -0.156356
# 3  [{'label': 'display', 'lat': 51.51703278849285...  51.517033 -0.155232
# 4  [{'label': 'display', 'lat': 51.51861880796264...  51.518619 -0.154835
#
#   neighborhood postalCode           state                        id
# 0          NaN    W1U 8EU  Greater London  5290a36511d23b77d9e8d1c4
# 1          NaN    W1U 8JF  Greater London  57076c36498eaefd5ce319da
# 2          NaN    W1U 8AB  Greater London  53f62a59498ea58f17690a49
# 3          NaN    W1U 3AH  Greater London  58c6abda7b88a758faedc68e
# 4          NaN    W1U 7PA  Greater London  5305f35711d21b05c826da58

# %% [markdown]
# #### As we see, again we have unwanted columns as we are working with fresh JSON data extracted from Foursquare - once again we need to undertake removal process

# %%
# Remove All the Unwanted Columns
london_hotel1.drop(['crossStreet', 'labeledLatLngs', 'postalCode', 'state', 'country', 'city', 'neighborhood', 'address', 'cc'], axis=1, inplace=True)
london_hotel2.drop(['crossStreet', 'labeledLatLngs', 'postalCode', 'state', 'country', 'city', 'neighborhood', 'address', 'cc'], axis=1, inplace=True)
london_hotel3.drop(['crossStreet', 'labeledLatLngs', 'postalCode', 'state', 'country', 'city', 'neighborhood', 'address', 'cc'], axis=1, inplace=True)
london_hotel4.drop(['crossStreet', 'labeledLatLngs', 'postalCode', 'state', 'country', 'city', 'neighborhood', 'address', 'cc'], axis=1, inplace=True)
london_hotel5.drop(['crossStreet', 'labeledLatLngs', 'postalCode', 'state', 'country', 'city', 'neighborhood', 'address', 'cc'], axis=1, inplace=True)

# %% [markdown]
# #### Let's see how it looks

# %%
london_hotel1.head()
# Out:
#                            name                  categories  \
# 0              DW Fitness First        Gym / Fitness Center
# 1  The Z Hotel Gloucester Place                       Hotel
# 2                      Carousel                  Restaurant
# 3               JOE & THE JUICE                   Juice Bar
# 4            Chiltern Firehouse  Modern European Restaurant
#
#                                     formattedAddress        lat       lng  \
# 0  [55 Baker St, London, Greater London, W1U 8EU,...  51.518798 -0.156122
# 1  [51 Gloucester Pl, London, Greater London, W1U...  51.518184 -0.158186
# 2  [71 Blandford St, London, Greater London, W1U ...  51.517992 -0.156356
# 3  [7 Baker Street, London, Greater London, W1U 3...  51.517033 -0.155232
# 4  [1 Chiltern St, London, Greater London, W1U 7P...  51.518619 -0.154835
#
#                          id
# 0  5290a36511d23b77d9e8d1c4
# 1  57076c36498eaefd5ce319da
# 2  53f62a59498ea58f17690a49
# 3  58c6abda7b88a758faedc68e
# 4  5305f35711d21b05c826da58

# %% [markdown]
# #### In the latest version of Folium, we cannot use special characters as this won't allow us to generate the map

# %%
london_hotel1 = london_hotel1.replace('\'','',regex=True)
london_hotel2 = london_hotel2.replace('\'','',regex=True)
london_hotel3 = london_hotel3.replace('\'','',regex=True)
london_hotel4 = london_hotel4.replace('\'','',regex=True)
london_hotel5 = london_hotel5.replace('\'','',regex=True)

# %% [markdown]
# # Now we can visualize the London map with hotels & Venues

# %%
london_map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add a marker to represent The Z Gloucseter Place
folium.Marker(
    [london_hotels_extract['lat'].iloc[0], london_hotels_extract['lng'].iloc[0]],
    popup=london_hotels_extract['name'].iloc[0],
).add_to(london_map)

# add the Nearby Places as blue circle markers
for lat, lng, label in zip(london_hotel1.lat, london_hotel1.lng, london_hotel1.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(london_map)
    
# add a marker to represent The Tower Hotel
folium.Marker(
    [london_hotels_extract['lat'].iloc[1], london_hotels_extract['lng'].iloc[1]],
    popup=london_hotels_extract['name'].iloc[1],
).add_to(london_map)

# add the Nearby Places as green circle markers
for lat1, lng1, label1 in zip(london_hotel2.lat, london_hotel2.lng, london_hotel2.name):
    folium.features.CircleMarker(
        [lat1, lng1],
        radius=5,
        color='green',
        popup=label1,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(london_map)
    
# add a marker to represent The Z Hotel Victoria
folium.Marker(
    [london_hotels_extract['lat'].iloc[2], london_hotels_extract['lng'].iloc[2]],
    popup=london_hotels_extract['name'].iloc[2],
).add_to(london_map)

# add the Nearby Places as orange circle markers
for lat, lng, label in zip(london_hotel3.lat, london_hotel3.lng, london_hotel3.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='orange',
        popup=label,
        fill = True,
        fill_color='orange',
        fill_opacity=0.6
    ).add_to(london_map)
    
# add a marker to represent Millenium & Copthorne Hotel
folium.Marker(
    [london_hotels_extract['lat'].iloc[3], london_hotels_extract['lng'].iloc[3]],
    popup=london_hotels_extract['name'].iloc[3],
).add_to(london_map)

# add the Nearby Places as purple circle markers
for lat, lng, label in zip(london_hotel4.lat, london_hotel4.lng, london_hotel4.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='purple',
        popup=label,
        fill = True,
        fill_color='purple',
        fill_opacity=0.6
    ).add_to(london_map)
    
# add a marker to represent The Z Hotel Soho
folium.Marker(
    [london_hotels_extract['lat'].iloc[4], london_hotels_extract['lng'].iloc[4]],
    popup=london_hotels_extract['name'].iloc[4],
).add_to(london_map)

# add the Nearby Places as red circle markers
for lat, lng, label in zip(london_hotel5.lat, london_hotel5.lng, london_hotel5.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(london_map)

# display map
london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Looking at the map we can clearly see that 'Z' family hotels have most concentrated venues within the range. Given that 'Gloucester place' belongs to the 'Z' family and it has the highest rating - then we have our best choice of hotel in London!

# %% [markdown]
# #### For the user information we can create quick handbook about top5 hotels and the most popular venue within the range

# %%
d = {'Hotel': london_hotels_extract['name'], 'Most Popular Venue in area': [
    london_hotel1.groupby('categories',as_index=False).count().sort_values(by='name', ascending=False).iloc[1,0],
    london_hotel2.groupby('categories',as_index=False).count().sort_values(by='name', ascending=False).iloc[1,0],
    london_hotel3.groupby('categories',as_index=False).count().sort_values(by='name', ascending=False).iloc[1,0],
    london_hotel4.groupby('categories',as_index=False).count().sort_values(by='name', ascending=False).iloc[1,0],
    london_hotel5.groupby('categories',as_index=False).count().sort_values(by='name', ascending=False).iloc[1,0]
]}

Handbook = pd.DataFrame()

Handbook = pd.DataFrame(data=d)

# %%
Handbook
# Out:
#                                  Hotel Most Popular Venue in area
# Ratings
# 8.8       The Z Hotel Gloucester Place         Chinese Restaurant
# 7.6                    The Tower Hotel                Coffee Shop
# 7.4               The Z Hotel Victoria         Italian Restaurant
# 6.4      Millennium & Copthorne Hotels                       Café
# 5.8                   The Z Hotel Soho             Ice Cream Shop

# %% [markdown]
# ***

# %% [markdown]
# # Results and Discussion

# %% [markdown]
# This project has started from capturing the data about the hotels within the 10km range. Next using this data we have managed to obtain the ratings for them - this allowed us to select top 5 hotels within the range. As we know rating is not the only requirement for tourists, but a venues around. Given the hotel data we have managed to get the venues in a range of 1 km and succesfully visualized them on a map of London. When examining the map we can clearly see the biggest concentration of venues in the 'Z' family of hotels. The hotel with the highest rating overall is 'The Z Hotel Gloucester Place' - it does belong to the 'Z' family of hotels. Assuming that rating + venues concentration are these 2 main requirements we can state that 'The Z Hotel Gloucester Place' was chosen as the best place to stay in London.

# %% [markdown]
# # Future improvements

# %% [markdown]
# + We can add to analysis the average price for a room and customer's preferences for the venue type, to prepare deep personalized analysis
# + We can enhance this project to analyze every big city in the world

# %% [markdown]
# # Conclusion

# %% [markdown]
# The purpose of this project was to help tourists to find the best place to stay - this is one of the most important factors when deciding about the trip. Preferences greatly differ for every individual, but there is one common value - "What is others opinion about this place" ? This has placed the fundamentals for this project, but we have gone 1 step ahead and tried to answer the second question "What i can do there once im placed in hotel" ? Combining these two charactersitics allows us to navigate to the best hotel in city - with highest rating and big concentration of venues nearby. We have made our choice in terms of which hotel is the best as per dataset, but we know that it still might not be the best for the person who is planning a trip. In order to satisfy the most people, we have created a small leaflet about the most popular venues around the top 5 places to stay - I'm sure this will be helpful to anyone going to London this year :)

# %% [markdown]
# # Thank you for reaching to the end! - have a great day
